# %%
import os
import json
import numpy as np
import pandas as pd
import requests

# %%
#!/usr/bin/env python

def APIjsonReturnProject(token):
#!/usr/bin/env python

    data = {
        'token': token,
        'content': 'record',
        'action': 'export',
        'format': 'csv',
        'type': 'flat',
        'csvDelimiter': '',
        'records[0]': '1',
        'records[1]': '2',
        'records[2]': '9832-1',
        'records[3]': '9832-2',
        'records[4]': '9836-1',
        'records[5]': '9842-1',
        'records[6]': '9842-2',
        'records[7]': '9842-3',
        'records[8]': '9856-1',
        'records[9]': '9861-1',
        'records[10]': '9861-2',
        'records[11]': '9861-3',
        'records[12]': '9871-1',
        'records[13]': '9882-1',
        'records[14]': 'Broadview',
        'records[15]': 'Fairfield',
        'records[16]': 'Lavina',
        'records[17]': 'St. Regis',
        'records[18]': 'Superior',
        'fields[0]': 'proj_id',
        'fields[1]': 'class_name',
        'fields[2]': 'a_school',
        'fields[3]': 'year',
        'fields[4]': 'class_type',
        'fields[5]': 'class_type_other',
        'fields[6]': 'a_first_1',
        'fields[7]': 'a_last_1',
        'fields[8]': 'a_dob_1',
        'fields[9]': 'a_grade_1',
        'fields[10]': 'a_gradeother_1',
        'fields[11]': 'a_sex_1',
        'fields[12]': 'a_race_1',
        'fields[13]': 'a_consent_1',
        'fields[14]': 'a_first_2',
        'fields[15]': 'a_last_2',
        'fields[16]': 'a_dob_2',
        'fields[17]': 'a_grade_2',
        'fields[18]': 'a_gradeother_2',
        'fields[19]': 'a_sex_2',
        'fields[20]': 'a_race_2',
        'fields[21]': 'a_consent_2',
        'fields[22]': 'a_first_3',
        'fields[23]': 'a_last_3',
        'fields[24]': 'a_dob_3',
        'fields[25]': 'a_grade_3',
        'fields[26]': 'a_gradeother_3',
        'fields[27]': 'a_sex_3',
        'fields[28]': 'a_race_3',
        'fields[29]': 'a_consent_3',
        'fields[30]': 'a_first_4',
        'fields[31]': 'a_last_4',
        'fields[32]': 'a_dob_4',
        'fields[33]': 'a_grade_4',
        'fields[34]': 'a_gradeother_4',
        'fields[35]': 'a_sex_4',
        'fields[36]': 'a_race_4',
        'fields[37]': 'a_consent_4',
        'fields[38]': 'a_first_5',
        'fields[39]': 'a_last_5',
        'fields[40]': 'a_dob_5',
        'fields[41]': 'a_grade_5',
        'fields[42]': 'a_gradeother_5',
        'fields[43]': 'a_sex_5',
        'fields[44]': 'a_race_5',
        'fields[45]': 'a_consent_5',
        'fields[46]': 'a_first_6',
        'fields[47]': 'a_last_6',
        'fields[48]': 'a_dob_6',
        'fields[49]': 'a_grade_6',
        'fields[50]': 'a_gradeother_6',
        'fields[51]': 'a_sex_6',
        'fields[52]': 'a_race_6',
        'fields[53]': 'a_consent_6',
        'fields[54]': 'a_first_7',
        'fields[55]': 'a_last_7',
        'fields[56]': 'a_dob_7',
        'fields[57]': 'a_grade_7',
        'fields[58]': 'a_gradeother_7',
        'fields[59]': 'a_sex_7',
        'fields[60]': 'a_race_7',
        'fields[61]': 'a_consent_7',
        'fields[62]': 'a_first_8',
        'fields[63]': 'a_last_8',
        'fields[64]': 'a_dob_8',
        'fields[65]': 'a_grade_8',
        'fields[66]': 'a_gradeother_8',
        'fields[67]': 'a_sex_8',
        'fields[68]': 'a_race_8',
        'fields[69]': 'a_consent_8',
        'fields[70]': 'a_first_9',
        'fields[71]': 'a_last_9',
        'fields[72]': 'a_dob_9',
        'fields[73]': 'a_grade_9',
        'fields[74]': 'a_gradeother_9',
        'fields[75]': 'a_sex_9',
        'fields[76]': 'a_race_9',
        'fields[77]': 'a_consent_9',
        'fields[78]': 'a_first_10',
        'fields[79]': 'a_last_10',
        'fields[80]': 'a_dob_10',
        'fields[81]': 'a_grade_10',
        'fields[82]': 'a_gradeother_10',
        'fields[83]': 'a_sex_10',
        'fields[84]': 'a_race_10',
        'fields[85]': 'a_consent_10',
        'fields[86]': 'a_first_11',
        'fields[87]': 'a_last_11',
        'fields[88]': 'a_dob_11',
        'fields[89]': 'a_grade_11',
        'fields[90]': 'a_gradeother_11',
        'fields[91]': 'a_sex_11',
        'fields[92]': 'a_race_11',
        'fields[93]': 'a_consent_11',
        'fields[94]': 'a_first_12',
        'fields[95]': 'a_last_12',
        'fields[96]': 'a_dob_12',
        'fields[97]': 'a_grade_12',
        'fields[98]': 'a_gradeother_12',
        'fields[99]': 'a_sex_12',
        'fields[100]': 'a_race_12',
        'fields[101]': 'a_consent_12',
        'fields[102]': 'a_first_13',
        'fields[103]': 'a_last_13',
        'fields[104]': 'a_dob_13',
        'fields[105]': 'a_grade_13',
        'fields[106]': 'a_gradeother_13',
        'fields[107]': 'a_sex_13',
        'fields[108]': 'a_race_13',
        'fields[109]': 'a_consent_13',
        'fields[110]': 'a_first_14',
        'fields[111]': 'a_last_14',
        'fields[112]': 'a_dob_14',
        'fields[113]': 'a_grade_14',
        'fields[114]': 'a_gradeother_14',
        'fields[115]': 'a_sex_14',
        'fields[116]': 'a_race_14',
        'fields[117]': 'a_consent_14',
        'fields[118]': 'a_first_15',
        'fields[119]': 'a_last_15',
        'fields[120]': 'a_dob_15',
        'fields[121]': 'a_grade_15',
        'fields[122]': 'a_gradeother_15',
        'fields[123]': 'a_sex_15',
        'fields[124]': 'a_race_15',
        'fields[125]': 'a_consent_15',
        'fields[126]': 'a_first_16',
        'fields[127]': 'a_last_16',
        'fields[128]': 'a_dob_16',
        'fields[129]': 'a_grade_16',
        'fields[130]': 'a_gradeother_16',
        'fields[131]': 'a_sex_16',
        'fields[132]': 'a_race_16',
        'fields[133]': 'a_consent_16',
        'fields[134]': 'a_first_17',
        'fields[135]': 'a_last_17',
        'fields[136]': 'a_dob_17',
        'fields[137]': 'a_grade_17',
        'fields[138]': 'a_gradeother_17',
        'fields[139]': 'a_sex_17',
        'fields[140]': 'a_race_17',
        'fields[141]': 'a_consent_17',
        'fields[142]': 'a_first_18',
        'fields[143]': 'a_last_18',
        'fields[144]': 'a_dob_18',
        'fields[145]': 'a_grade_18',
        'fields[146]': 'a_gradeother_18',
        'fields[147]': 'a_sex_18',
        'fields[148]': 'a_race_18',
        'fields[149]': 'a_consent_18',
        'fields[150]': 'a_first_19',
        'fields[151]': 'a_last_19',
        'fields[152]': 'a_dob_19',
        'fields[153]': 'a_grade_19',
        'fields[154]': 'a_gradeother_19',
        'fields[155]': 'a_sex_19',
        'fields[156]': 'a_race_19',
        'fields[157]': 'a_consent_19',
        'fields[158]': 'a_first_20',
        'fields[159]': 'a_last_20',
        'fields[160]': 'a_dob_20',
        'fields[161]': 'a_grade_20',
        'fields[162]': 'a_gradeother_20',
        'fields[163]': 'a_sex_20',
        'fields[164]': 'a_race_20',
        'fields[165]': 'a_consent_20',
        'fields[166]': 'a_first_21',
        'fields[167]': 'a_last_21',
        'fields[168]': 'a_dob_21',
        'fields[169]': 'a_grade_21',
        'fields[170]': 'a_gradeother_21',
        'fields[171]': 'a_sex_21',
        'fields[172]': 'a_race_21',
        'fields[173]': 'a_consent_21',
        'fields[174]': 'a_first_22',
        'fields[175]': 'a_last_22',
        'fields[176]': 'a_dob_22',
        'fields[177]': 'a_grade_22',
        'fields[178]': 'a_gradeother_22',
        'fields[179]': 'a_sex_22',
        'fields[180]': 'a_race_22',
        'fields[181]': 'a_consent_22',
        'fields[182]': 'a_first_23',
        'fields[183]': 'a_last_23',
        'fields[184]': 'a_dob_23',
        'fields[185]': 'a_grade_23',
        'fields[186]': 'a_gradeother_23',
        'fields[187]': 'a_sex_23',
        'fields[188]': 'a_race_23',
        'fields[189]': 'a_consent_23',
        'fields[190]': 'a_first_24',
        'fields[191]': 'a_last_24',
        'fields[192]': 'a_dob_24',
        'fields[193]': 'a_grade_24',
        'fields[194]': 'a_gradeother_24',
        'fields[195]': 'a_sex_24',
        'fields[196]': 'a_race_24',
        'fields[197]': 'a_consent_24',
        'fields[198]': 'a_first_25',
        'fields[199]': 'a_last_25',
        'fields[200]': 'a_dob_25',
        'fields[201]': 'a_grade_25',
        'fields[202]': 'a_gradeother_25',
        'fields[203]': 'a_sex_25',
        'fields[204]': 'a_race_25',
        'fields[205]': 'a_consent_25',
        'fields[206]': 'a_first_26',
        'fields[207]': 'a_last_26',
        'fields[208]': 'a_dob_26',
        'fields[209]': 'a_grade_26',
        'fields[210]': 'a_gradeother_26',
        'fields[211]': 'a_sex_26',
        'fields[212]': 'a_race_26',
        'fields[213]': 'a_consent_26',
        'fields[214]': 'a_first_27',
        'fields[215]': 'a_last_27',
        'fields[216]': 'a_dob_27',
        'fields[217]': 'a_grade_27',
        'fields[218]': 'a_gradeother_27',
        'fields[219]': 'a_sex_27',
        'fields[220]': 'a_race_27',
        'fields[221]': 'a_consent_27',
        'fields[222]': 'a_first_28',
        'fields[223]': 'a_last_28',
        'fields[224]': 'a_dob_28',
        'fields[225]': 'a_grade_28',
        'fields[226]': 'a_gradeother_28',
        'fields[227]': 'a_sex_28',
        'fields[228]': 'a_race_28',
        'fields[229]': 'a_consent_28',
        'fields[230]': 'a_first_29',
        'fields[231]': 'a_last_29',
        'fields[232]': 'a_dob_29',
        'fields[233]': 'a_grade_29',
        'fields[234]': 'a_gradeother_29',
        'fields[235]': 'a_sex_29',
        'fields[236]': 'a_race_29',
        'fields[237]': 'a_consent_29',
        'fields[238]': 'a_first_30',
        'fields[239]': 'a_last_30',
        'fields[240]': 'a_dob_30',
        'fields[241]': 'a_grade_30',
        'fields[242]': 'a_gradeother_30',
        'fields[243]': 'a_sex_30',
        'fields[244]': 'a_race_30',
        'fields[245]': 'a_consent_30',
        'fields[246]': 'a_first_31',
        'fields[247]': 'a_last_31',
        'fields[248]': 'a_dob_31',
        'fields[249]': 'a_grade_31',
        'fields[250]': 'a_gradeother_31',
        'fields[251]': 'a_sex_31',
        'fields[252]': 'a_race_31',
        'fields[253]': 'a_consent_31',
        'fields[254]': 'a_first_32',
        'fields[255]': 'a_last_32',
        'fields[256]': 'a_dob_32',
        'fields[257]': 'a_grade_32',
        'fields[258]': 'a_gradeother_32',
        'fields[259]': 'a_sex_32',
        'fields[260]': 'a_race_32',
        'fields[261]': 'a_consent_32',
        'fields[262]': 'a_first_33',
        'fields[263]': 'a_last_33',
        'fields[264]': 'a_dob_33',
        'fields[265]': 'a_grade_33',
        'fields[266]': 'a_gradeother_33',
        'fields[267]': 'a_sex_33',
        'fields[268]': 'a_race_33',
        'fields[269]': 'a_consent_33',
        'fields[270]': 'a_first_34',
        'fields[271]': 'a_last_34',
        'fields[272]': 'a_dob_34',
        'fields[273]': 'a_grade_34',
        'fields[274]': 'a_gradeother_34',
        'fields[275]': 'a_sex_34',
        'fields[276]': 'a_race_34',
        'fields[277]': 'a_consent_34',
        'fields[278]': 'a_first_35',
        'fields[279]': 'a_last_35',
        'fields[280]': 'a_dob_35',
        'fields[281]': 'a_grade_35',
        'fields[282]': 'a_gradeother_35',
        'fields[283]': 'a_sex_35',
        'fields[284]': 'a_race_35',
        'fields[285]': 'a_consent_35',
        'fields[286]': 'students_complete',
        'fields[287]': 'a_date_lesson1',
        'fields[288]': 'a_date_lesson2',
        'fields[289]': 'a_date_lesson3',
        'fields[290]': 'a_date_lesson4',
        'fields[291]': 'a_date_lesson5',
        'fields[292]': 'attend_1',
        'fields[293]': 'attend_2',
        'fields[294]': 'attend_3',
        'fields[295]': 'attend_4',
        'fields[296]': 'attend_5',
        'fields[297]': 'attend_6',
        'fields[298]': 'attend_7',
        'fields[299]': 'attend_8',
        'fields[300]': 'attend_9',
        'fields[301]': 'attend_10',
        'fields[302]': 'attend_11',
        'fields[303]': 'attend_12',
        'fields[304]': 'attend_13',
        'fields[305]': 'attend_14',
        'fields[306]': 'attend_15',
        'fields[307]': 'attend_16',
        'fields[308]': 'attend_17',
        'fields[309]': 'attend_18',
        'fields[310]': 'attend_19',
        'fields[311]': 'attend_20',
        'fields[312]': 'attend_21',
        'fields[313]': 'attend_22',
        'fields[314]': 'attend_23',
        'fields[315]': 'attend_24',
        'fields[316]': 'attend_25',
        'fields[317]': 'attend_26',
        'fields[318]': 'attend_27',
        'fields[319]': 'attend_28',
        'fields[320]': 'attend_29',
        'fields[321]': 'attend_30',
        'fields[322]': 'attend_31',
        'fields[323]': 'attend_32',
        'fields[324]': 'attend_33',
        'fields[325]': 'attend_34',
        'fields[326]': 'attend_35',
        'fields[327]': 'attendance_sheet_complete',
        'fields[328]': 'f_complete_pre',
        'fields[329]': 'f_min_pre',
        'fields[330]': 'f_date_pre',
        'fields[331]': 'presurvey_log_complete',
        'fields[332]': 'f_teacher_1',
        'fields[333]': 'f_min_1',
        'fields[334]': 'f_gender_1',
        'fields[335]': 'f_a_1',
        'fields[336]': 'f_a_complete_1',
        'fields[337]': 'f_a_date_1',
        'fields[338]': 'f_a_follow_1',
        'fields[339]': 'f_a_change_1',
        'fields[340]': 'f_a_change_describe_1',
        'fields[341]': 'f_a_why_1',
        'fields[342]': 'f_b_1',
        'fields[343]': 'f_b_complete_1',
        'fields[344]': 'f_b_date_1',
        'fields[345]': 'f_b_follow_1',
        'fields[346]': 'f_b_change_1',
        'fields[347]': 'f_b_change_describe_1',
        'fields[348]': 'f_b_why_1',
        'fields[349]': 'f_c_1',
        'fields[350]': 'f_c_complete_1',
        'fields[351]': 'f_c_date_1',
        'fields[352]': 'f_c_follow_1',
        'fields[353]': 'f_c_change_1',
        'fields[354]': 'f_c_change_describe_1',
        'fields[355]': 'f_c_why_1',
        'fields[356]': 'f_d_1',
        'fields[357]': 'f_d_complete_1',
        'fields[358]': 'f_d_date_1',
        'fields[359]': 'f_d_follow_1',
        'fields[360]': 'f_d_change_1',
        'fields[361]': 'f_d_change_describe_1',
        'fields[362]': 'f_d_why_1',
        'fields[363]': 'f_e_1',
        'fields[364]': 'f_e_complete_1',
        'fields[365]': 'f_e_date_1',
        'fields[366]': 'f_e_follow_1',
        'fields[367]': 'f_e_change_1',
        'fields[368]': 'f_e_change_describe_1',
        'fields[369]': 'f_e_why_1',
        'fields[370]': 'f_f_1',
        'fields[371]': 'f_f_complete_1',
        'fields[372]': 'f_f_date_1',
        'fields[373]': 'f_f_follow_1',
        'fields[374]': 'f_f_change_1',
        'fields[375]': 'f_f_change_describe_1',
        'fields[376]': 'f_f_why_1',
        'fields[377]': 'f_comments_1',
        'fields[378]': 'lesson_1_log_complete',
        'fields[379]': 'f_teacher_2',
        'fields[380]': 'f_min_2',
        'fields[381]': 'f_gender_2',
        'fields[382]': 'f_a_2',
        'fields[383]': 'f_a_complete_2',
        'fields[384]': 'f_a_date_2',
        'fields[385]': 'f_a_follow_2',
        'fields[386]': 'f_a_change_2',
        'fields[387]': 'f_a_change_describe_2',
        'fields[388]': 'f_a_why_2',
        'fields[389]': 'f_b_2',
        'fields[390]': 'f_b_complete_2',
        'fields[391]': 'f_b_date_2',
        'fields[392]': 'f_b_follow_2',
        'fields[393]': 'f_b_change_2',
        'fields[394]': 'f_b_change_describe_2',
        'fields[395]': 'f_b_why_2',
        'fields[396]': 'f_c_2',
        'fields[397]': 'f_c_complete_2',
        'fields[398]': 'f_c_date_2',
        'fields[399]': 'f_c_follow_2',
        'fields[400]': 'f_c_change_2',
        'fields[401]': 'f_c_change_describe_2',
        'fields[402]': 'f_c_why_2',
        'fields[403]': 'f_d_2',
        'fields[404]': 'f_d_complete_2',
        'fields[405]': 'f_d_date_2',
        'fields[406]': 'f_d_follow_2',
        'fields[407]': 'f_d_change_2',
        'fields[408]': 'f_d_change_describe_2',
        'fields[409]': 'f_d_why_2',
        'fields[410]': 'f_e_2',
        'fields[411]': 'f_e_complete_2',
        'fields[412]': 'f_e_date_2',
        'fields[413]': 'f_e_follow_2',
        'fields[414]': 'f_e_change_2',
        'fields[415]': 'f_e_change_describe_2',
        'fields[416]': 'f_e_why_2',
        'fields[417]': 'f_f_2',
        'fields[418]': 'f_f_complete_2',
        'fields[419]': 'f_f_date_2',
        'fields[420]': 'f_f_follow_2',
        'fields[421]': 'f_f_change_2',
        'fields[422]': 'f_f_change_describe_2',
        'fields[423]': 'f_f_why_2',
        'fields[424]': 'f_comments_2',
        'fields[425]': 'lesson_2_log_complete',
        'fields[426]': 'f_teacher_3',
        'fields[427]': 'f_min_3',
        'fields[428]': 'f_gender_3',
        'fields[429]': 'f_a_3',
        'fields[430]': 'f_a_complete_3',
        'fields[431]': 'f_a_date_3',
        'fields[432]': 'f_a_follow_3',
        'fields[433]': 'f_a_change_3',
        'fields[434]': 'f_a_change_describe_3',
        'fields[435]': 'f_a_why_3',
        'fields[436]': 'f_b_3',
        'fields[437]': 'f_b_complete_3',
        'fields[438]': 'f_b_date_3',
        'fields[439]': 'f_b_follow_3',
        'fields[440]': 'f_b_change_3',
        'fields[441]': 'f_b_change_describe_3',
        'fields[442]': 'f_b_why_3',
        'fields[443]': 'f_c_3',
        'fields[444]': 'f_c_complete_3',
        'fields[445]': 'f_c_date_3',
        'fields[446]': 'f_c_follow_3',
        'fields[447]': 'f_c_change_3',
        'fields[448]': 'f_c_change_describe_3',
        'fields[449]': 'f_c_why_3',
        'fields[450]': 'f_d_3',
        'fields[451]': 'f_d_complete_3',
        'fields[452]': 'f_d_date_3',
        'fields[453]': 'f_d_follow_3',
        'fields[454]': 'f_d_change_3',
        'fields[455]': 'f_d_change_describe_3',
        'fields[456]': 'f_d_why_3',
        'fields[457]': 'f_e_3',
        'fields[458]': 'f_e_complete_3',
        'fields[459]': 'f_e_date_3',
        'fields[460]': 'f_e_follow_3',
        'fields[461]': 'f_e_change_3',
        'fields[462]': 'f_e_change_describe_3',
        'fields[463]': 'f_e_why_3',
        'fields[464]': 'f_f_3',
        'fields[465]': 'f_f_complete_3',
        'fields[466]': 'f_f_date_3',
        'fields[467]': 'f_f_follow_3',
        'fields[468]': 'f_f_change_3',
        'fields[469]': 'f_f_change_describe_3',
        'fields[470]': 'f_f_why_3',
        'fields[471]': 'f_comments_3',
        'fields[472]': 'lesson_3_log_complete',
        'fields[473]': 'f_teacher_4',
        'fields[474]': 'f_min_4',
        'fields[475]': 'f_gender_4',
        'fields[476]': 'f_a_4',
        'fields[477]': 'f_a_complete_4',
        'fields[478]': 'f_a_date_4',
        'fields[479]': 'f_a_follow_4',
        'fields[480]': 'f_a_change_4',
        'fields[481]': 'f_a_change_describe_4',
        'fields[482]': 'f_a_why_4',
        'fields[483]': 'f_b_4',
        'fields[484]': 'f_b_complete_4',
        'fields[485]': 'f_b_date_4',
        'fields[486]': 'f_b_follow_4',
        'fields[487]': 'f_b_change_4',
        'fields[488]': 'f_b_change_describe_4',
        'fields[489]': 'f_b_why_4',
        'fields[490]': 'f_c_4',
        'fields[491]': 'f_c_complete_4',
        'fields[492]': 'f_c_date_4',
        'fields[493]': 'f_c_follow_4',
        'fields[494]': 'f_c_change_4',
        'fields[495]': 'f_c_change_describe_4',
        'fields[496]': 'f_c_why_4',
        'fields[497]': 'f_d_4',
        'fields[498]': 'f_d_complete_4',
        'fields[499]': 'f_d_date_4',
        'fields[500]': 'f_d_follow_4',
        'fields[501]': 'f_d_change_4',
        'fields[502]': 'f_d_change_describe_4',
        'fields[503]': 'f_d_why_4',
        'fields[504]': 'f_e_4',
        'fields[505]': 'f_e_complete_4',
        'fields[506]': 'f_e_date_4',
        'fields[507]': 'f_e_follow_4',
        'fields[508]': 'f_e_change_4',
        'fields[509]': 'f_e_change_describe_4',
        'fields[510]': 'f_e_why_4',
        'fields[511]': 'f_f_4',
        'fields[512]': 'f_f_complete_4',
        'fields[513]': 'f_f_date_4',
        'fields[514]': 'f_f_follow_4',
        'fields[515]': 'f_f_change_4',
        'fields[516]': 'f_f_change_describe_4',
        'fields[517]': 'f_f_why_4',
        'fields[518]': 'f_g_4',
        'fields[519]': 'f_g_complete_4',
        'fields[520]': 'f_g_date_4',
        'fields[521]': 'f_g_follow_4',
        'fields[522]': 'f_g_change_4',
        'fields[523]': 'f_g_change_describe_4',
        'fields[524]': 'f_g_why_4',
        'fields[525]': 'f_comments_4',
        'fields[526]': 'lesson_4_log_complete',
        'fields[527]': 'f_teacher_5',
        'fields[528]': 'f_min_5',
        'fields[529]': 'f_gender_5',
        'fields[530]': 'f_a_5',
        'fields[531]': 'f_a_complete_5',
        'fields[532]': 'f_a_date_5',
        'fields[533]': 'f_a_follow_5',
        'fields[534]': 'f_a_change_5',
        'fields[535]': 'f_a_change_describe_5',
        'fields[536]': 'f_a_why_5',
        'fields[537]': 'f_b_5',
        'fields[538]': 'f_b_complete_5',
        'fields[539]': 'f_b_date_5',
        'fields[540]': 'f_b_follow_5',
        'fields[541]': 'f_b_change_5',
        'fields[542]': 'f_b_change_describe_5',
        'fields[543]': 'f_b_why_5',
        'fields[544]': 'f_c_5',
        'fields[545]': 'f_c_complete_5',
        'fields[546]': 'f_c_date_5',
        'fields[547]': 'f_c_follow_5',
        'fields[548]': 'f_c_change_5',
        'fields[549]': 'f_c_change_describe_5',
        'fields[550]': 'f_c_why_5',
        'fields[551]': 'f_d_5',
        'fields[552]': 'f_d_complete_5',
        'fields[553]': 'f_d_date_5',
        'fields[554]': 'f_d_follow_5',
        'fields[555]': 'f_d_change_5',
        'fields[556]': 'f_d_change_describe_5',
        'fields[557]': 'f_d_why_5',
        'fields[558]': 'f_e_5',
        'fields[559]': 'f_e_complete_5',
        'fields[560]': 'f_e_date_5',
        'fields[561]': 'f_e_follow_5',
        'fields[562]': 'f_e_change_5',
        'fields[563]': 'f_e_change_describe_5',
        'fields[564]': 'f_e_why_5',
        'fields[565]': 'f_comments_5',
        'fields[566]': 'lesson_5_log_complete',
        'fields[567]': 'f_complete_post',
        'fields[568]': 'f_min_post',
        'fields[569]': 'f_date_post',
        'fields[570]': 'postsurvey_log_complete',
        'fields[571]': 'teacher_length',
        'fields[572]': 'previous_puso',
        'fields[573]': 'previous_puso_years',
        'fields[574]': 'previous_puso_school',
        'fields[575]': 'boost_pack',
        'fields[576]': 'boost_pack_number',
        'fields[577]': 'boost_pack_list',
        'fields[578]': 'other_programs',
        'fields[579]': 'other_programs_list',
        'fields[580]': 'accept_gradelevel',
        'fields[581]': 'wellreceive',
        'fields[582]': 'wellreceive_lesson',
        'fields[583]': 'problematic',
        'fields[584]': 'problematic_lesson',
        'fields[585]': 'problematic_why',
        'fields[586]': 'recommend',
        'fields[587]': 'recommend_yes_why',
        'fields[588]': 'recommend_no_why',
        'fields[589]': 'feasible_time',
        'fields[590]': 'inperson_train',
        'fields[591]': 'toolkit',
        'fields[592]': 'toolkit_wout_train',
        'fields[593]': 'feasible_difficulty',
        'fields[594]': 'relevancy',
        'fields[595]': 'engagement',
        'fields[596]': 'engagement_compare',
        'fields[597]': 'student_safety',
        'fields[598]': 'student_unsafe',
        'fields[599]': 'bullymonth',
        'fields[600]': 'bullyweek',
        'fields[601]': 'overall',
        'fields[602]': 'anything_else',
        'fields[603]': 'teacher_post_survey_complete',
        'fields[604]': 'f_complete_follow',
        'fields[605]': 'f_min_follow',
        'fields[606]': 'f_date_follow',
        'fields[607]': 'followupsurvey_log_complete',
        'forms[0]': 'students',
        'rawOrLabel': 'raw',
        'rawOrLabelHeaders': 'raw',
        'exportCheckboxLabel': 'false',
        'exportSurveyFields': 'false',
        'exportDataAccessGroups': 'false',
        'returnFormat': 'json'
    }
    r = requests.post('https://redcap.iths.org/api/',data=data)
    print('HTTP Status: ' + str(r.status_code))
    print(r.text)

    return r.text
    r.close()

# %%
#APIjsonReturnProject('1B6180BA0C1BF6DFF75109C00D5CD59E')[0] # Call to project 2
#APIjsonReturnProject('4847408F8A88FAB4554C9F5628D4AF9E') # Call to project 3

# %%
import sys


def classesOut():
    final = []
    f = row1.index('proj_id')
    classes = [[] for i in xrange(0)]
    classes.append(rowNum[f:row1.index('class_type_other')])
    final.append(classes[0])
    print('')

    return final


def studentsOut():
    h = 1
    i = 2
    e = 5
    final = []
    try:
        while e < row1.index('students_complete'):
            students = [[] for i in xrange(0)]
            students.append(rowNum[row1.index('a_first_'+str(h)):\
                                 row1.index('a_first_'+str(i))])
            final.append(students[0])
            i = i + 1
            h = h + 1
            e = e + (row1.index('a_first_'+str(i))-row1.index('a_first_'+str(h)))
    except Exception as e: pass

    return final,e
            

def attendOut():
    f = 1
    h = 5
    final = []
    attendSmall = []
    attendSmall.append(row1[row1.index('attendance_sheet_complete')-1])
    small = str(attendSmall[0])
    s = int(small[-1])
    b = int(small[-6]+small[-5])
    r = row1.index('attend_1___1')
    try:
        while r < row1.index('attendance_sheet_complete'):
            attend = [[] for i in xrange(0)]
            attend.append(rowNum[row1.index('attend_'+str(f)+'___1'):\
                               (row1.index('attend_'+str(f)+'___'+str(s))+1)])
            final.append(attend[0])
            f = f + 1
            r = r + 1
    except Exception as e: pass

    return final,s,e


def lessonLogOut():
    i = 1
    final = []
    LL1S = row1.index('f_teacher_1')
    try:
        while LL1S < row1.index('f_complete_post'):
            lesson = [[] for i in xrange(0)]
            lesson.append(rowNum[row1.index('f_teacher_'+str(i)):\
                               (row1.index('lesson_'+str(i)+'_log_complete'))])
            final.append(lesson[0])
            i = i + 1
            LL1S = LL1S + 1
    except Exception as e: pass

    return final,e


def rowsWriter():
    attend = []
    labels = []
    final = []
    dataJoined = [(e1 + e2 + e3) for (e1, e2, e3)\
                      in zip(studentsOut()[0],attendOut()[0],lessonLogOut()[0])]
    
    for i in range(1,attendOut()[1]+1):
        attend.append('attend'+'_'+str(i))
                               
    labels.append(['a_first','a_last','a_dob','a_grade','a_gradeother',\
                           'a_sex','a_race_1','a_race_2','a_race_3',\
                           'a_race_4', 'a_race_5','a_race_6','a_race_7'])

    final = labels[0] + attend
    with open(input_+'_Row'+row+'_Output.csv','wb') as data:
        filename = csv.writer(data)
        filename.writerows(classesOut())
        filename.writerow(final)
        for line in dataJoined:
            filename.writerow(line)

    with open(input_+'_Row'+row+'_Err_Rep.csv','wb') as info:
        filename2 = csv.writer(info)
        filename2.writerow([studentsOut()[1]])
        filename2.writerow([attendOut()[2]])
        filename2.writerow([lessonLogOut()[1]])
        filename2.writerow(APIjsonReturnProject('4847408F8A88FAB4554C9F5628D4AF9E'))

    raw_input('File was created. Press ENTER to exit')
    sys.exit(0)

rowsWriter()

# %%
os.chdir('//state.mt.ads/HHS/Shared/ECFSD/BSO/Adolescent Health Power Up project')

import csv

def jSonWriter(functionCall,fileOut):
    with open(fileOut, 'w', encoding='utf-8') as f:
        json.dump(functionCall, f, ensure_ascii=False, indent=4)
    #f.close()

#jSonWriter(APIjsonReturnProject('1B6180BA0C1BF6DFF75109C00D5CD59E')[0],'PUSO_data_Project_2.txt')
#jSonWriter(APIjsonReturnProject('4847408F8A88FAB4554C9F5628D4AF9E')[0],'PUSO_data_Project_3.txt')

# %%
import json

os.chdir('//state.mt.ads/HHS/Shared/ECFSD/BSO/Adolescent Health Power Up project')

def jSonYield(file_):
    ids = []
    titleList = []
    data = json.load(open(file_))
    pos0 = list(data.keys())
    pos1 = list(data.values())
    
    dataDict = dict(zip(pos0,pos1))
    print(dataDict)

# %%
jSonYield('PUSO_data_Project_2.json')

# %%
jSonYield('PUSO_data.json')
